# %%
len(नेपाली)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5f3d0e64f87> in <module>()
# ----> 1 len(नेपाली)
#
# NameError: name 'नेपाली' is not defined

# %% [markdown]
# # Day 3
# ---
#
# Problem: Determine frequency of words for given paragraph.
#
# Uses:
# - Dictionary
# - List
# - String Functions
# - While
# - If condition

# %%
paragraph="""A man entered who could hardly have been less than six feet six
inches in height, with the chest and limbs of a Hercules. His
dress was rich with a richness which would, in England, be looked
upon as akin to bad taste. Heavy bands of astrakhan were slashed
across the sleeves and fronts of his double-breasted coat, while
the deep blue cloak which was thrown over his shoulders was lined
with flame-coloured silk and secured at the neck with a brooch
which consisted of a single flaming beryl. Boots which extended
halfway up his calves, and which were trimmed at the tops with
rich brown fur, completed the impression of barbaric opulence
which was suggested by his whole appearance. He carried a
broad-brimmed hat in his hand, while he wore across the upper
part of his face, extending down past the cheekbones, a black
vizard mask, which he had apparently adjusted that very moment,
for his hand was still raised to it as he entered. From the lower
part of the face he appeared to be a man of strong character,
with a thick, hanging lip, and a long, straight chin suggestive
of resolution pushed to the length of obstinacy."""
words=paragraph.split()

# %%
words
# Out:
# ['A',
#  'man',
#  'entered',
#  'who',
#  'could',
#  'hardly',
#  'have',
#  'been',
#  'less',
#  'than',
#  'six',
#  'feet',
#  'six',
#  'inches',
#  'in',
#  'height,',
#  'with',
#  'the',
#  'chest',
#  'and',
#  'limbs',
#  'of',
#  'a',
#  'Hercules.',
#  'His',
#  'dress',
#  'was',
#  'rich',
#  'with',
#  'a',
#  'richness',
#  'which',
#  'would,',
#  'in',
#  'England,',
#  'be',
#  'looked',
#  'upon',
#  'as',
#  'akin',
#  'to',
#  'bad',
#  'taste.',
#  'Heavy',
#  'bands',
#  'of',
#  'astrakhan',
#  'were',
#  'slashed',
#  'across',
#  'the',
#  'sleeves',
#  'and',
#  'fronts',
#  'of',
#  'his',
#  'double-breasted',
#  'coat,',
#  'while',
#  'the',
#  'deep',
#  'blue',
#  'cloak',
#  'which',
#  'was',
#  'thrown',
#  'over',
#  'his',
#  'shoulders',
#  'was',
#  'lined',
#  'with',
#  'flame-coloured',
#  'silk',
#  'and',
#  'secured',
#  'at',
#  'the',
#  'neck',
#  'with',
#  'a',
#  'brooch',
#  'which',
#  'consisted',
#  'of',
#  'a',
#  'single',
#  'flaming',
#  'beryl.',
#  'Boots',
#  'which',
#  'extended',
#  'halfway',
#  'up',
#  'his',
#  'calves,',
#  'and',
#  'which',
#  'were',
#  'trimmed',
#  'at',
#  'the',
#  'tops',
#  'with',
#  'rich',
#  'brown',
#  'fur,',
#  'completed',
#  'the',
#  'impression',
#  'of',
#  'barbaric',
#  'opulence',
#  'which',
#  'was',
#  'suggested',
#  'by',
#  'his',
#  'whole',
#  'appearance.',
#  'He',
#  'carried',
#  'a',
#  'broad-brimmed',
#  'hat',
#  'in',
#  'his',
#  'hand,',
#  'while',
#  'he',
#  'wore',
#  'across',
#  'the',
#  'upper',
#  'part',
#  'of',
#  'his',
#  'face,',
#  'extending',
#  'down',
#  'past',
#  'the',
#  'cheekbones,',
#  'a',
#  'black',
#  'vizard',
#  'mask,',
#  'which',
#  'he',
#  'had',
#  'apparently',
#  'adjusted',
#  'that',
#  'very',
#  'moment,',
#  'for',
#  'his',
#  'hand',
#  'was',
#  'still',
#  'raised',
#  'to',
#  'it',
#  'as',
#  'he',
#  'entered.',
#  'From',
#  'the',
#  'lower',
#  'part',
#  'of',
#  'the',
#  'face',
#  'he',
#  'appeared',
#  'to',
#  'be',
#  'a',
#  'man',
#  'of',
#  'strong',
#  'character,',
#  'with',
#  'a',
#  'thick,',
#  'hanging',
#  'lip,',
#  'and',
#  'a',
#  'long,',
#  'straight',
#  'chin',
#  'suggestive',
#  'of',
#  'resolution',
#  'pushed',
#  'to',
#  'the',
#  'length',
#  'of',
#  'obstinacy.']

# %%
index=0
while index < len(words):
    print(index,words[index])    
    index+=1
print("Number of words", len(words)+1)
# Out:
# 0 A
# 1 man
# 2 entered
# 3 who
# 4 could
# 5 hardly
# 6 have
# 7 been
# 8 less
# 9 than
# 10 six
# 11 feet
# 12 six
# 13 inches
# 14 in
# 15 height,
# 16 with
# 17 the
# 18 chest
# 19 and
# 20 limbs
# 21 of
# 22 a
# 23 Hercules.
# 24 His
# 25 dress
# 26 was
# 27 rich
# 28 with
# 29 a
# 30 richness
# 31 which
# 32 would,
# 33 in
# 34 England,
# 35 be
# 36 looked
# 37 upon
# 38 as
# 39 akin
# 40 to
# 41 bad
# 42 taste.
# 43 Heavy
# 44 bands
# 45 of
# 46 astrakhan
# 47 were
# 48 slashed
# 49 across
# 50 the
# 51 sleeves
# 52 and
# 53 fronts
# 54 of
# 55 his
# 56 double-breasted
# 57 coat,
# 58 while
# 59 the
# 60 deep
# 61 blue
# 62 cloak
# 63 which
# 64 was
# 65 thrown
# 66 over
# 67 his
# 68 shoulders
# 69 was
# 70 lined
# 71 with
# 72 flame-coloured
# 73 silk
# 74 and
# 75 secured
# 76 at
# 77 the
# 78 neck
# 79 with
# 80 a
# 81 brooch
# 82 which
# 83 consisted
# 84 of
# 85 a
# 86 single
# 87 flaming
# 88 beryl.
# 89 Boots
# 90 which
# 91 extended
# 92 halfway
# 93 up
# 94 his
# 95 calves,
# 96 and
# 97 which
# 98 were
# 99 trimmed
# 100 at
# 101 the
# 102 tops
# 103 with
# 104 rich
# 105 brown
# 106 fur,
# 107 completed
# 108 the
# 109 impression
# 110 of
# 111 barbaric
# 112 opulence
# 113 which
# 114 was
# 115 suggested
# 116 by
# 117 his
# 118 whole
# 119 appearance.
# 120 He
# 121 carried
# 122 a
# 123 broad-brimmed
# 124 hat
# 125 in
# 126 his
# 127 hand,
# 128 while
# 129 he
# 130 wore
# 131 across
# 132 the
# 133 upper
# 134 part
# 135 of
# 136 his
# 137 face,
# 138 extending
# 139 down
# 140 past
# 141 the
# 142 cheekbones,
# 143 a
# 144 black
# 145 vizard
# 146 mask,
# 147 which
# 148 he
# 149 had
# 150 apparently
# 151 adjusted
# 152 that
# 153 very
# 154 moment,
# 155 for
# 156 his
# 157 hand
# 158 was
# 159 still
# 160 raised
# 161 to
# 162 it
# 163 as
# 164 he
# 165 entered.
# 166 From
# 167 the
# 168 lower
# 169 part
# 170 of
# 171 the
# 172 face
# 173 he
# 174 appeared
# 175 to
# 176 be
# 177 a
# 178 man
# 179 of
# 180 strong
# 181 character,
# 182 with
# 183 a
# 184 thick,
# 185 hanging
# 186 lip,
# 187 and
# 188 a
# 189 long,
# 190 straight
# 191 chin
# 192 suggestive
# 193 of
# 194 resolution
# 195 pushed
# 196 to
# 197 the
# 198 length
# 199 of
# 200 obstinacy.
# Number of words 202

# %%
freq={}
index=0
while index < len(words):
    freq[words[index].strip(',').strip('.').lower()]=0
    #word=words[index]
    #word=word.strip(',')
    #word=word.strip('.')
    #word=word.lower()
    index+=1
print(freq)
# Out:
# {'a': 0, 'man': 0, 'entered': 0, 'who': 0, 'could': 0, 'hardly': 0, 'have': 0, 'been': 0, 'less': 0, 'than': 0, 'six': 0, 'feet': 0, 'inches': 0, 'in': 0, 'height': 0, 'with': 0, 'the': 0, 'chest': 0, 'and': 0, 'limbs': 0, 'of': 0, 'hercules': 0, 'his': 0, 'dress': 0, 'was': 0, 'rich': 0, 'richness': 0, 'which': 0, 'would': 0, 'england': 0, 'be': 0, 'looked': 0, 'upon': 0, 'as': 0, 'akin': 0, 'to': 0, 'bad': 0, 'taste': 0, 'heavy': 0, 'bands': 0, 'astrakhan': 0, 'were': 0, 'slashed': 0, 'across': 0, 'sleeves': 0, 'fronts': 0, 'double-breasted': 0, 'coat': 0, 'while': 0, 'deep': 0, 'blue': 0, 'cloak': 0, 'thrown': 0, 'over': 0, 'shoulders': 0, 'lined': 0, 'flame-coloured': 0, 'silk': 0, 'secured': 0, 'at': 0, 'neck': 0, 'brooch': 0, 'consisted': 0, 'single': 0, 'flaming': 0, 'beryl': 0, 'boots': 0, 'extended': 0, 'halfway': 0, 'up': 0, 'calves': 0, 'trimmed': 0, 'tops': 0, 'brown': 0, 'fur': 0, 'completed': 0, 'impression': 0, 'barbaric': 0, 'opulence': 0, 'suggested': 0, 'by': 0, 'whole': 0, 'appearance': 0, 'he': 0, 'carried': 0, 'broad-brimmed': 0, 'hat': 0, 'hand': 0, 'wore': 0, 'upper': 0, 'part': 0, 'face': 0, 'extending': 0, 'down': 0, 'past': 0, 'cheekbones': 0, 'black': 0, 'vizard': 0, 'mask': 0, 'had': 0, 'apparently': 0, 'adjusted': 0, 'that': 0, 'very': 0, 'moment': 0, 'for': 0, 'still': 0, 'raised': 0, 'it': 0, 'from': 0, 'lower': 0, 'appeared': 0, 'strong': 0, 'character': 0, 'thick': 0, 'hanging': 0, 'lip': 0, 'long': 0, 'straight': 0, 'chin': 0, 'suggestive': 0, 'resolution': 0, 'pushed': 0, 'length': 0, 'obstinacy': 0}

# %%
freq={}
index=0
while index<len(words):
    word=words[index].strip('.').strip(',').lower()
    if word in freq:
        freq[word]+=1
    else:
        freq[word]=1
    index+=1
print(freq)
# Out:
# {'a': 10, 'man': 2, 'entered': 2, 'who': 1, 'could': 1, 'hardly': 1, 'have': 1, 'been': 1, 'less': 1, 'than': 1, 'six': 2, 'feet': 1, 'inches': 1, 'in': 3, 'height': 1, 'with': 6, 'the': 11, 'chest': 1, 'and': 5, 'limbs': 1, 'of': 10, 'hercules': 1, 'his': 8, 'dress': 1, 'was': 5, 'rich': 2, 'richness': 1, 'which': 7, 'would': 1, 'england': 1, 'be': 2, 'looked': 1, 'upon': 1, 'as': 2, 'akin': 1, 'to': 4, 'bad': 1, 'taste': 1, 'heavy': 1, 'bands': 1, 'astrakhan': 1, 'were': 2, 'slashed': 1, 'across': 2, 'sleeves': 1, 'fronts': 1, 'double-breasted': 1, 'coat': 1, 'while': 2, 'deep': 1, 'blue': 1, 'cloak': 1, 'thrown': 1, 'over': 1, 'shoulders': 1, 'lined': 1, 'flame-coloured': 1, 'silk': 1, 'secured': 1, 'at': 2, 'neck': 1, 'brooch': 1, 'consisted': 1, 'single': 1, 'flaming': 1, 'beryl': 1, 'boots': 1, 'extended': 1, 'halfway': 1, 'up': 1, 'calves': 1, 'trimmed': 1, 'tops': 1, 'brown': 1, 'fur': 1, 'completed': 1, 'impression': 1, 'barbaric': 1, 'opulence': 1, 'suggested': 1, 'by': 1, 'whole': 1, 'appearance': 1, 'he': 5, 'carried': 1, 'broad-brimmed': 1, 'hat': 1, 'hand': 2, 'wore': 1, 'upper': 1, 'part': 2, 'face': 2, 'extending': 1, 'down': 1, 'past': 1, 'cheekbones': 1, 'black': 1, 'vizard': 1, 'mask': 1, 'had': 1, 'apparently': 1, 'adjusted': 1, 'that': 1, 'very': 1, 'moment': 1, 'for': 1, 'still': 1, 'raised': 1, 'it': 1, 'from': 1, 'lower': 1, 'appeared': 1, 'strong': 1, 'character': 1, 'thick': 1, 'hanging': 1, 'lip': 1, 'long': 1, 'straight': 1, 'chin': 1, 'suggestive': 1, 'resolution': 1, 'pushed': 1, 'length': 1, 'obstinacy': 1}

# %%
nfreq={'a':1,'b':2}
'c' in nfreq
'a' in nfreq
# Out:
# True

# %% [markdown]
# # Boolean operation
# - True
# - False
