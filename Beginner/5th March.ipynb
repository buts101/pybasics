# %% [markdown]
# # Day 1
# ---
# # Numpy

# %%
from scipy import misc

# %%
misc.face()
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
face=misc.face()

# %%
face.ndim
# Out:
# 3

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pylab as plt

# %%
# %matplotlib inline

# %%
plt.imshow(face)

# %%
face[:20].shape
# Out:
# (20, 1024, 3)

# %%
face[:20,:20].shape
# Out:
# (20, 20, 3)

# %%
plt.imshow(face[:200,:400])

# %%
import numpy as np

# %%
arr=np.array([12,10,18])

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (3,)

# %%
arr2=np.array([[10,17,19],[12,16,18]])

# %%
arr2.ndim #dimensions of the array
# Out:
# 2

# %%
arr2.shape #matrix shape of the array
# Out:
# (2, 3)

# %%
arr2
# Out:
# array([[10, 17, 19],
#        [12, 16, 18]])

# %%
face.size
# Out:
# 2359296

# %%
arr2.size #number of elements in the array
# Out:
# 6

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
arr2[0][:2] #for selecting only 10,17
# Out:
# array([10, 17])

# %%
arr2[0,:2] # another method to select the array elements
# Out:
# array([10, 17])

# %%
face[:2,:2,:3]
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121]]], dtype=uint8)

# %%
arr2[:2,:2]
# Out:
# array([[10, 17],
#        [12, 16]])

# %%
arr2[:,::2]
# Out:
# array([[10, 19],
#        [12, 18]])

# %%
arr2[:,1]
# Out:
# array([17, 16])

# %%
face[:,:,1]
# Out:
# array([[112, 129, 144, ..., 126, 136, 144],
#        [ 82, 103, 122, ..., 125, 141, 153],
#        [ 66,  87, 108, ..., 126, 142, 153],
#        ...,
#        [106, 110, 124, ..., 158, 157, 158],
#        [101, 111, 127, ..., 157, 156, 156],
#        [101, 113, 126, ..., 156, 155, 154]], dtype=uint8)

# %%
plt.imshow(face[:,:,:3])

# %% [markdown]
# - Heatmap
# - Colormap

# %% [markdown]
# - Jet colormap
# - virisdis colormap

# %%
help(misc)
# Out:
# Help on package scipy.misc in scipy:
#
# NAME
#     scipy.misc
#
# DESCRIPTION
# ...
#     Miscellaneous routines (:mod:`scipy.misc`)
# ...
#
#     .. currentmodule:: scipy.misc
#
#     Various utilities that don't have another home.
#
#     Note that the Python Imaging Library (PIL) is not a dependency
#     of SciPy and therefore the `pilutil` module is not available on
#     systems that don't have PIL installed.
#
#     .. autosummary::
#        :toctree: generated/
#
#        ascent - Get example image for processing
#        bytescale - Byte scales an array (image)
#        central_diff_weights - Weights for an n-point central m-th derivative
#        comb - Combinations of N things taken k at a time, "N choose k" (imported from scipy.special)
#        derivative - Find the n-th derivative of a function at a point
#        face - Get example image for processing
#        factorial  - The factorial function, n! = special.gamma(n+1) (imported from scipy.special)
# ...

# %%
plt.imshow(misc.lena())
# Out:
# --------------------------------------------------------------------------
# RuntimeError                             Traceback (most recent call last)
# <ipython-input-68-f0cea6ecb600> in <module>()
# ----> 1 plt.imshow(misc.lena())
#
# /home/ashish/anaconda3/lib/python3.6/site-packages/scipy/misc/common.py in lena()
#     332     face, ascent
#     333     """
# --> 334     raise RuntimeError('lena() is no longer included in SciPy, please use '
#     335                        'ascent() or face() instead')
#     336
#
# RuntimeError: lena() is no longer included in SciPy, please use ascent() or face() instead

# %%
misc.ascent()
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
plt.imshow(misc.ascent())

# %%
arr2.transpose()
# Out:
# array([[10, 12],
#        [17, 16],
#        [19, 18]])
